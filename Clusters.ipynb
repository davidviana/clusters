# %% [markdown]
# <a href="https://colab.research.google.com/github/davidviana/clusters/blob/main/Clusters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import math as Math

# %%
x, y = make_blobs(n_samples=300, centers=3, cluster_std=0.70, random_state=0)
plt.scatter(x[:, 0], x[:, 1])

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred = kmeans.fit_predict(x)
plt.scatter(x[:,0], x[:,1], c=kmeans.labels_)

# centroides
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], c='red', s=50)
plt.show()

# %%
# metodo do cotovelo
wcss = []
for n in range(2, 10):
    kmeans = KMeans(n_clusters=n, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

plt.plot(range(2, 10), wcss)
plt.title('Método do Cutovelo')
plt.show()

# %%
# distance

x1, y1 = 2, wcss[0]
x2, y2 = 9, wcss[-1]

distances = []
for i in range(len(wcss)):
    x0 = i + 2
    y0 = wcss[i]
    numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
    denominator = Math.sqrt((y2 - y1)**2 + (x2 - x1)**2)
    res = (numerator/denominator)
    distances.append(res)
  
optimal_clusters = distances.index(max(distances)) + 2

print(f'Distances: {distances};')
print(f'Clusters Ideal: {optimal_clusters};')
# Out:
# Distances: [1.7602070954922103e-15, 4.107607548456002, 3.58882050143182, 2.9627483198500797, 2.286948575435046, 1.5637723398525492, 0.7967776012949725, 2.77927436130349e-16];
# Clusters Ideal: 3;

# %% [markdown]
# Exercicio 1

# %%
X = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12, 10, 4, 3, 11, 14]
Y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21, 17, 16, 25, 24, 22]
plt.scatter(X, Y)

data = list(zip(X, Y))

# %%
# metodo do cotovelo EX 1
wcss_1 = []
for n in range(2, 10):
    kmeans = KMeans(n_clusters=n, init='k-means++', max_iter=len(data))
    kmeans.fit(data)
    wcss_1.append(kmeans.inertia_)

plt.plot(range(2, 10), wcss_1)
plt.title('Método do Cutovelo')
plt.show()

# %%
x1, y1 = 2, wcss_1[0]
x2, y2 = 9, wcss_1[-1]

distances = []
for i in range(len(wcss_1)):
    x0 = i + 2
    y0 = wcss_1[i]
    numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
    denominator = Math.sqrt((y2 - y1)**2 + (x2 - x1)**2)
    res = (numerator/denominator)
    distances.append(res)
  
optimal_clusters = distances.index(max(distances)) + 2

print(f'Clusters Ideal: {optimal_clusters};')
# Out:
# Clusters Ideal: 4;

# %% [markdown]
# Exercicios 2

# %%
X, y = make_blobs(n_samples=100, random_state=170)
plt.scatter(X[:,0], X[:,1])

# %%
# metodo do cotovelo EX 2
wcss_2 = []
for n in range(2, 10):
    kmeans = KMeans(n_clusters=n, init='k-means++', max_iter=100, random_state=170)
    kmeans.fit(X)
    wcss_2.append(kmeans.inertia_)

plt.plot(range(2, 10), wcss_2)
plt.title('Método do Cutovelo')
plt.show()

# %%
x1, y1 = 2, wcss_2[0]
x2, y2 = 9, wcss_2[-1]

distances = []
for i in range(len(wcss_2)):
    x0 = i + 2
    y0 = wcss_2[i]
    numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
    denominator = Math.sqrt((y2 - y1)**2 + (x2 - x1)**2)
    res = (numerator/denominator)
    distances.append(res)
  
optimal_clusters = distances.index(max(distances)) + 2

print(f'Clusters Ideal: {optimal_clusters};')
# Out:
# Clusters Ideal: 3;

# %% [markdown]
# Exercicio 3

# %%
X, y = make_blobs(n_samples=100,random_state=0)
plt.scatter(X[:,0], X[:,1])

# %%
# metodo do cotovelo EX 3
wcss_3 = []
for n in range(2, 10):
    kmeans = KMeans(n_clusters=n, init='k-means++', max_iter=100, random_state=0)
    kmeans.fit(X)
    wcss_3.append(kmeans.inertia_)

plt.plot(range(2, 10), wcss_3)
plt.title('Método do Cutovelo')
plt.show()

# %%
x1, y1 = 2, wcss_3[0]
x2, y2 = 9, wcss_3[-1]

distances = []
for i in range(len(wcss_3)):
    x0 = i + 2
    y0 = wcss_3[i]
    numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
    denominator = Math.sqrt((y2 - y1)**2 + (x2 - x1)**2)
    res = (numerator/denominator)
    distances.append(res)
  
optimal_clusters = distances.index(max(distances)) + 2

print(f'Clusters Ideal: {optimal_clusters};')
# Out:
# Clusters Ideal: 3;
